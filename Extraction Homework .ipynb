# %% [markdown]
# # Week 7 - Information Extraction
# This week, we move from arbitrary textual classification to the use of computation and linguistic models to parse precise claims from documents. Rather than focusing on simply the ideas in a corpus, here we focus on understanding and extracting its precise claims. This process involves a sequential pipeline of classifying and structuring tokens from text, each of which generates potentially useful data for the content analyst. Steps in this process, which we examine in this notebook, include: 1) tagging words by their part of speech (POS) to reveal the linguistic role they play in the sentence (e.g., Verb, Noun, Adjective, etc.); 2) tagging words as named entities (NER) such as places or organizations; 3) structuring or "parsing" sentences into nested phrases that are local to, describe or depend on one another; and 4) extracting informational claims from those phrases, like the Subject-Verb-Object (SVO) triples we extract here. While much of this can be done directly in the python package NLTK that we introduced in week 2, here we use NLTK bindings to the Stanford NLP group's open software, written in Java. Try typing a sentence into the online version here to get a sense of its potential. It is superior in performance to NLTK's implementations, but takes time to run, and so for these exercises we will parse and extract information for a very small text corpus. Of course, for final projects that draw on these tools, we encourage you to install the software on your own machines or shared servers at the university (RCC, SSRC) in order to perform these operations on much more text.
#
# For this notebook we will be using the following packages:

# %%
#Special module written for this class
#This provides access to data and to helper functions from previous weeks
#Make sure you update it before starting this notebook
import lucem_illud #pip install -U git+git://github.com/Computational-Content-Analysis-2018/lucem_illud.git

#All these packages need to be installed from pip
#For NLP
import nltk

import numpy as np #For arrays
import pandas #Gives us DataFrames
import matplotlib.pyplot as plt #For graphics
import seaborn #Makes the graphics look nicer

#Displays the graphs
import graphviz #You also need to install the command line graphviz

#These are from the standard library
import os.path
import zipfile
import subprocess
import io
import tempfile

# %matplotlib inline

# %% [markdown]
# You need to run this once to download everything, you will also need Java 1.8+ if you are using Windows or MacOS.

# %%
lucem_illud.setupStanfordNLP()
# Out:
# Starting downloads, this will take 5-10 minutes
# ../stanford-NLP/parser already exists, skipping download
# ../stanford-NLP/ner already exists, skipping download
# ../stanford-NLP/postagger already exists, skipping download
# ../stanford-NLP/core already exists, skipping download
# Done setting up the Stanford NLP collection

# %% [markdown]
# We need to have stanford-NLP setup before importing, so we are doing the import here. IF you have stanford-NLP working, you can import at the beginning like you would with any other library.

# %%
import lucem_illud.stanford as stanford
# Out:
# /software/Anaconda3-5.0.0.1-el7-x86_64/lib/python3.6/site-packages/nltk/tag/stanford.py:183: DeprecationWarning:
# The StanfordTokenizer will be deprecated in version 3.2.5.
# Please use nltk.tag.corenlp.CoreNLPPOSTagger or nltk.tag.corenlp.CoreNLPNERTagger instead.
#   super(StanfordNERTagger, self).__init__(*args, **kwargs)
# /software/Anaconda3-5.0.0.1-el7-x86_64/lib/python3.6/site-packages/nltk/tag/stanford.py:149: DeprecationWarning:
# The StanfordTokenizer will be deprecated in version 3.2.5.
# Please use nltk.tag.corenlp.CoreNLPPOSTagger or nltk.tag.corenlp.CoreNLPNERTagger instead.
#   super(StanfordPOSTagger, self).__init__(*args, **kwargs)

# %% [markdown]
# Open Information Extraction is a module packaged within the Stanford Core NLP package, but it is not yet supported by nltk. As a result, we have defining our own lucem_illud function that runs the Stanford Core NLP java code right here. For other projects, it is often useful to use Java or other programs (in C, C++) within a python workflow, and this is an example. stanford.openIE() takes in a string or list of strings and then produces as output all the subject, verb, object (SVO) triples Stanford Corenlp can find, as a DataFrame. You can do this through links to the Stanford Core NLP project that we provide here, or play with their interface directly (in the penultimate cell of this notebook), which produces data in "pretty graphics" like this example parsing of the first sentence in the "Shooting of Trayvon Martin" Wikipedia article:
#
# First, we will illustrate these tools on some very short examples:

# %%
text = ['I saw the elephant in my pajamas.', 'The quick brown fox jumped over the lazy dog.', 'While in France, Christine Lagarde discussed short-term stimulus efforts in a recent interview with the Wall Street Journal.', 'Trayvon Benjamin Martin was an African American from Miami Gardens, Florida, who, at 17 years old, was fatally shot by George Zimmerman, a neighborhood watch volunteer, in Sanford, Florida.', 'Buffalo buffalo Buffalo buffalo buffalo buffalo Buffalo buffalo']
tokenized_text = [nltk.word_tokenize(t) for t in text]
print('\n'.join(text))
# Out:
# I saw the elephant in my pajamas.
# The quick brown fox jumped over the lazy dog.
# While in France, Christine Lagarde discussed short-term stimulus efforts in a recent interview with the Wall Street Journal.
# Trayvon Benjamin Martin was an African American from Miami Gardens, Florida, who, at 17 years old, was fatally shot by George Zimmerman, a neighborhood watch volunteer, in Sanford, Florida.
# Buffalo buffalo Buffalo buffalo buffalo buffalo Buffalo buffalo

# %%
print(tokenized_text[2])
# Out:
# ['While', 'in', 'France', ',', 'Christine', 'Lagarde', 'discussed', 'short-term', 'stimulus', 'efforts', 'in', 'a', 'recent', 'interview', 'with', 'the', 'Wall', 'Street', 'Journal', '.']

# %% [markdown]
# Part-of-Speech (POS) tagging
# In POS tagging, we classify each word by its semantic role in a sentence. The Stanford POS tagger uses the Penn Treebank tag set to POS tag words from input sentences. As discussed in the second assignment, this is a relatively precise tagset, which allows more informative tags, and also more opportunities to err :-).
#
# #.	Tag	Description
# 1.	CC	Coordinating conjunction
# 2.	CD	Cardinal number
# 3.	DT	Determiner
# 4.	EX	Existential there
# 5.	FW	Foreign word
# 6.	IN	Preposition or subordinating conjunction
# 7.	JJ	Adjective
# 8.	JJR	Adjective, comparative
# 9.	JJS	Adjective, superlative
# 10.	LS	List item marker
# 11.	MD	Modal
# 12.	NN	Noun, singular or mass
# 13.	NNS	Noun, plural
# 14.	NNP	Proper noun, singular
# 15.	NNPS	Proper noun, plural
# 16.	PDT	Predeterminer
# 17.	POS	Possessive ending
# 18.	PRP	Personal pronoun
# 19.	PRP\$	Possessive pronoun
# 20.	RB	Adverb
# 21.	RBR	Adverb, comparative
# 22.	RBS	Adverb, superlative
# 23.	RP	Particle
# 24.	SYM	Symbol
# 25.	TO	to
# 26.	UH	Interjection
# 27.	VB	Verb, base form
# 28.	VBD	Verb, past tense
# 29.	VBG	Verb, gerund or present participle
# 30.	VBN	Verb, past participle
# 31.	VBP	Verb, non-3rd person singular present
# 32.	VBZ	Verb, 3rd person singular present
# 33.	WDT	Wh-determiner
# 34.	WP	Wh-pronoun
# 35.	WP$	Possessive wh-pronoun
# 36.	WRB	Wh-adverb

# %%
pos_sents = stanford.postTagger.tag_sents(tokenized_text)
print(pos_sents)
# Out:
# [[('I', 'PRP'), ('saw', 'VBD'), ('the', 'DT'), ('elephant', 'NN'), ('in', 'IN'), ('my', 'PRP$'), ('pajamas', 'NNS'), ('.', '.')], [('The', 'DT'), ('quick', 'JJ'), ('brown', 'JJ'), ('fox', 'NN'), ('jumped', 'VBD'), ('over', 'IN'), ('the', 'DT'), ('lazy', 'JJ'), ('dog', 'NN'), ('.', '.')], [('While', 'IN'), ('in', 'IN'), ('France', 'NNP'), (',', ','), ('Christine', 'NNP'), ('Lagarde', 'NNP'), ('discussed', 'VBD'), ('short-term', 'JJ'), ('stimulus', 'NN'), ('efforts', 'NNS'), ('in', 'IN'), ('a', 'DT'), ('recent', 'JJ'), ('interview', 'NN'), ('with', 'IN'), ('the', 'DT'), ('Wall', 'NNP'), ('Street', 'NNP'), ('Journal', 'NNP'), ('.', '.')], [('Trayvon', 'NNP'), ('Benjamin', 'NNP'), ('Martin', 'NNP'), ('was', 'VBD'), ('an', 'DT'), ('African', 'NNP'), ('American', 'NNP'), ('from', 'IN'), ('Miami', 'NNP'), ('Gardens', 'NNP'), (',', ','), ('Florida', 'NNP'), (',', ','), ('who', 'WP'), (',', ','), ('at', 'IN'), ('17', 'CD'), ('years', 'NNS'), ('old', 'JJ'), (',', ','), ('was', 'VBD'), ('fatally', 'RB'), ('shot', 'VBN'), ('by', 'IN'), ('George', 'NNP'), ('Zimmerman', 'NNP'), (',', ','), ('a', 'DT'), ('neighborhood', 'NN'), ('watch', 'NN'), ('volunteer', 'NN'), (',', ','), ('in', 'IN'), ('Sanford', 'NNP'), (',', ','), ('Florida', 'NNP'), ('.', '.')], [('Buffalo', 'NNP'), ('buffalo', 'NN'), ('Buffalo', 'NNP'), ('buffalo', 'NN'), ('buffalo', 'NN'), ('buffalo', 'NN'), ('Buffalo', 'NNP'), ('buffalo', 'NN')]]

# %% [markdown]
# This looks quite good. Now we will try POS tagging with a somewhat larger corpus. We consider a few of the top posts from the reddit data we used last week.

# %%
redditDF = pandas.read_csv('../data/reddit.csv', index_col=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-9caabdb38d0b> in <module>()
# ----> 1 redditDF = pandas.read_csv('../data/reddit.csv', index_col=0)
#
# ~/.local/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     707                     skip_blank_lines=skip_blank_lines)
#     708
# --> 709         return _read(filepath_or_buffer, kwds)
#     710
#     711     parser_f.__name__ = name
#
# ~/.local/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     447
#     448     # Create the parser.
# --> 449     parser = TextFileReader(filepath_or_buffer, **kwds)
#     450
#     451     if chunksize or iterator:
#
# ~/.local/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     816             self.options['has_index_names'] = kwds['has_index_names']
#     817
# --> 818         self._make_engine(self.engine)
#     819
#     820     def close(self):
#
# ~/.local/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1047     def _make_engine(self, engine='c'):
#    1048         if engine == 'c':
# -> 1049             self._engine = CParserWrapper(self.f, **self.options)
#    1050         else:
#    1051             if engine == 'python':
#
# ~/.local/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1693         kwds['allow_leading_cols'] = self.index_col is not False
#    1694
# -> 1695         self._reader = parsers.TextReader(src, **kwds)
#    1696
#    1697         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'../data/reddit.csv' does not exist

# %% [markdown]
# Grabbing the 10 highest scoring posts and tokenizing the sentences. Once again, notice that we aren't going to do any kind of stemming this week (although semantic normalization may be performed where we translate synonyms into the same focal word).

# %%
redditTopScores = redditDF.sort_values('score')[-10:]
redditTopScores['sentences'] = redditTopScores['text'].apply(lambda x: [nltk.word_tokenize(s) for s in nltk.sent_tokenize(x)])
redditTopScores.index = range(len(redditTopScores) - 1, -1,-1) #Reindex to make things nice in the future
redditTopScores[-5:]

# %%
redditTopScores['POS_sents'] = redditTopScores['sentences'].apply(lambda x: stanford.postTagger.tag_sents(x))

# %%
redditTopScores['POS_sents']

# %% [markdown]
# And count the number of NN (nouns)

# %%
countTarget = 'NN'
targetCounts = {}
for entry in redditTopScores['POS_sents']:
    for sentence in entry:
        for ent, kind in sentence:
            if kind != countTarget:
                continue
            elif ent in targetCounts:
                targetCounts[ent] += 1
            else:
                targetCounts[ent] = 1
sortedTargets = sorted(targetCounts.items(), key = lambda x: x[1], reverse = True)
sortedTargets[:20]

# %% [markdown]
# What about the number of top verbs (VB)?

# %%
countTarget = 'VB'
targetCounts = {}
for entry in redditTopScores['POS_sents']:
    for sentence in entry:
        for ent, kind in sentence:
            if kind != countTarget:
                continue
            elif ent in targetCounts:
                targetCounts[ent] += 1
            else:
                targetCounts[ent] = 1
sortedTargets = sorted(targetCounts.items(), key = lambda x: x[1], reverse = True)
sortedTargets[:20]

# %% [markdown]
# What about the adjectives that modify the word, "computer"?

# %%
NTarget = 'JJ'
Word = 'computer'
NResults = set()
for entry in redditTopScores['POS_sents']:
    for sentence in entry:
        for (ent1, kind1),(ent2,kind2) in zip(sentence[:-1], sentence[1:]):
            if (kind1,ent2.lower())==(NTarget,Word):
                NResults.add(ent1)
            else:
                continue

print(NResults)

# %% [markdown]
# Evaluating POS tagger
# We can check the POS tagger by running it on a manually tagged corpus and identifying a reasonable error metric.

# %%
treeBank = nltk.corpus.treebank
treeBank.tagged_sents()[0]

# %%
treeBank.sents()[0]

# %%
stanfordTags = stanford.postTagger.tag_sents(treeBank.sents()[:30])

# %% [markdown]
# And compare the two

# %%
NumDiffs = 0
for sentIndex in range(len(stanfordTags)):
    for wordIndex in range(len(stanfordTags[sentIndex])):
        if stanfordTags[sentIndex][wordIndex][1] != treeBank.tagged_sents()[sentIndex][wordIndex][1]:
            if treeBank.tagged_sents()[sentIndex][wordIndex][1] != '-NONE-':
                print("Word: {}  \tStanford: {}\tTreebank: {}".format(stanfordTags[sentIndex][wordIndex][0], stanfordTags[sentIndex][wordIndex][1], treeBank.tagged_sents()[sentIndex][wordIndex][1]))
                NumDiffs += 1
total = sum([len(s) for s in stanfordTags])
print("The Precision is {:.3f}%".format((total-NumDiffs)/total * 100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a84a6a8f148e> in <module>()
#       1 NumDiffs = 0
# ----> 2 for sentIndex in range(len(stanfordTags)):
#       3     for wordIndex in range(len(stanfordTags[sentIndex])):
#       4         if stanfordTags[sentIndex][wordIndex][1] != treeBank.tagged_sents()[sentIndex][wordIndex][1]:
#       5             if treeBank.tagged_sents()[sentIndex][wordIndex][1] != '-NONE-':
#
# NameError: name 'stanfordTags' is not defined

# %% [markdown]
# So we can see that the stanford POS tagger is quite good. Nevertheless, for a 20 word sentence, we only have a 66% chance ($1-.96^{20}$) of tagging (and later parsing) it correctly.

# %% [markdown]
# *Exercise 1*
# In the cells immediately following, perform POS tagging on a meaningful (but modest) subset of a corpus associated with your final project. Examine the list of words associated with at least three different parts of speech. Consider conditional frequencies (e.g., adjectives associated with nouns of interest or adverbs with verbs of interest). What do these distributions suggest about your corpus?

# %%
#Load dataframe 
plos_df = pandas.read_pickle('data/plos_analysis/plos_normalized_sents_sample.pk1')

# %%
plos_df
# Out:
#                                       Article Contents Copyright Year  \
# 0    The study of animal communication is a complex...           2011
# 1    Aneurysms in general represent a Damocles swor...           2017
# 2    Prognostic information about life expectancy i...           2013
# 3    Interleukin (IL)-23 has been associated with t...           2017
# 4    Labor represents a stress test for the fetus. ...           2014
# 5    Competition has long been recognized as a crit...           2014
# 6    There were errors in the legend of Figure 11. ...           2012
# 7    Phylogeographic studies leverage spatial and g...           2017
# 8    Insulin-like Growth Factor-1 (IGF-1) is a pote...           2012
# 9    Despite the expansive development of targeted ...           2014
# 10   Many genetic studies of complex diseases are i...           2011
# 11   How our brains acquire stable cognitive maps o...           2013
# 12   The management of fragility fractures associat...           2011
# 13   Lymphangiogenesis is the process that forms ly...           None
# 14   Novel benzaldehyde compounds containing benzim...           2013
# 15   Although there are no systematic differences i...           2013
# 16   According to the definition of the US Institut...           2017
# 17   About 10% of the 135 million babies born every...           2016
# 18   Fetal growth is under the control of genetic, ...           2014
# 19   From 2005 through 2009, the number of people i...           2012
# 20   Dengue and dengue hemorrhagic fever (DF and DH...           2011
# 21   In surgery, the results of a randomized contro...           None
# 22   Cost-of-illness (COI) studies provide estimate...           2016
# 23   Vaccination against rumen methanogens has the ...           2016
# 24   MicroRNAs (miRNAs) belong to a group of endoge...           2013
# 25   Clear cell carcinoma (CCC) of the ovary is kno...           2016
# 26   Senescence is the physiological deterioration ...           2007
# 27   Chronic inflammation is associated with obesit...           None
# 28   Text was erroneously omitted from Figure 1. Th...           2013
# 29   Myopia has been shown to be a risk factor for ...           2017
# ..                                                 ...            ...
# 970  In the past two decades there has been an over...           2013
# 971  In order to understand complex biological netw...           None
# 972  Soy contains various bioactive components, whi...           2012
# 973  An emerging literature suggests that posttraum...           2013
# 974  Despite decades of intensive research and cons...           2015
# 975  There is a typographical error in the title of...           2009
# 976  Renal cell carcinoma (RCC) is a common maligna...           2016
# 977  Despite numerous recommendations calling for t...           2017
# 978  Inflammatory bowel disease (IBD), such as ulce...           2016
# 979  The use of fire by early hominins is considere...           2017
# 980  Nicotinic acetylcholine receptors (nAChR), in ...           2012
# 981  Coccidioides immitis and C. posadasii are path...           2015
# 982  During the cell isolating process, hepatocytes...           2016
# 983  Vulvar carcinoma is a rare malignancy, with an...           2015
# 984  Currently, a community-wide effort is being pu...           2007
# 985  Reactivation of latent human cytomegalovirus (...           2015
# 986  White spot syndrome virus (WSSV; genus Whispov...           2014
# 987  Pneumonia is the most frequent cause of death ...           2014
# 988  Standard visual acuity (VA), which relies on a...           2015
# 989  The Notch pathway is highly conserved from inv...           2013
# 990  Foot-and-mouth disease (FMD) is one of the mos...           2015
# 991  Cells grow with a wide range of sizes and morp...           2011
# 992  Males evolved extravagant plumage, towering an...           2006
# 993  In addition to the cytoplasmic phospholipid me...           2016
# 994  The incidence of inflammatory bowel disease (I...           2015
# 995  Genetic hitchhiking is the cause of a severe r...           2013
# 996  Figure 8 has an error in the value under "R". ...           2013
# 997  The formation of new blood vessels is critical...           2014
# 998  Like most plant parasites, aphids require inti...           2010
# 999  The placenta is an organ that connects the fet...           2014
#
#                         Journal Title  \
# 0                            PLoS ONE
# 1                            PLOS ONE
# 2                            PLoS ONE
# 3                            PLOS ONE
# 4                            PLoS ONE
# 5                            PLoS ONE
# 6                            PLoS ONE
# 7                        PLOS Biology
# 8                            PLoS ONE
# 9                            PLoS ONE
# 10                           PLoS ONE
# 11                           PLoS ONE
# 12                           PLoS ONE
# 13                           PLOS ONE
# 14                           PLoS ONE
# 15                           PLoS ONE
# 16                           PLOS ONE
# 17                           PLOS ONE
# 18                           PLoS ONE
# 19                           PLoS ONE
# 20   PLoS Neglected Tropical Diseases
# 21                               None
# 22                           PLOS ONE
# 23                           PLOS ONE
# 24                           PLoS ONE
# 25                           PLOS ONE
# 26                           PLoS ONE
# 27                               None
# 28                           PLoS ONE
# 29                           PLOS ONE
# ..                                ...
# 970                          PLoS ONE
# 971                              None
# 972                          PLoS ONE
# 973                          PLoS ONE
# 974                          PLOS ONE
# 975                      PLoS Biology
# 976                          PLOS ONE
# 977                          PLOS ONE
# 978                          PLOS ONE
# 979                          PLOS ONE
# 980                          PLoS ONE
# 981                    PLOS Pathogens
# 982                          PLOS ONE
# 983                          PLOS ONE
# 984        PLoS Computational Biology
# 985                    PLOS Pathogens
# 986                          PLoS ONE
# 987                          PLoS ONE
# 988                          PLOS ONE
# 989                          PLoS ONE
# 990                          PLOS ONE
# 991                          PLoS ONE
# 992                      PLoS Biology
# 993                          PLOS ONE
# 994                     PLOS Genetics
# 995                          PLoS ONE
# 996                          PLoS ONE
# 997                          PLoS ONE
# 998                     PLoS Genetics
# 999                          PLoS ONE
#
#                                                 Titles  \
# 0    UV-Deprived Coloration Reduces Success in Mate...
# 1    Metabolomic profiling of ascending thoracic ao...
# 2    Predictive Value of a Profile of Routine Blood...
# 3    Continuous IL-23 stimulation drives ILC3 deple...
# 4    Assessment of Coupling between Trans-Abdominal...
# 5    Seaweed-Coral Interactions: Variance in Seawee...
# 6    Correction: The Zinc Dyshomeostasis Hypothesis...
# 7    A latitudinal phylogeographic diversity gradie...
# 8          E-Peptides Control Bioavailability of IGF-1
# 9    Advancements in the Development of HIF-1α-Acti...
# 10   Using an Uncertainty-Coding Matrix in Bayesian...
# 11   Spiking Neurons in a Hierarchical Self-Organiz...
# 12   Upregulation of Inflammatory Genes and Downreg...
# 13   δ-Catenin Activates Rho GTPase, Promotes Lymph...
# 14   Conjugation of Benzylvanillin and Benzimidazol...
# 15   Mental Rotational Ability Is Correlated with S...
# 16   Guideline appraisal with AGREE II: Systematic ...
# 17   Low Exercise Capacity Increases the Risk of Lo...
# 18   IGF-IR Signal Transduction Protein Content and...
# 19   Rethinking the “Pre” in Pre-Therapy Counseling...
# 20   Economic Impact of Dengue Illness and the Cost...
# 21   ASSIST Applicability Scoring of Surgical trial...
# 22   Economic Impact of Dementia by Disease Severit...
# 23   Vaccination of Sheep with a Methanogen Protein...
# 24   MicroRNA Transcriptome in Swine Small Intestin...
# 25   Preclinical Investigations of PM01183 (Lurbine...
# 26   Predation by Bears Drives Senescence in Natura...
# 27   Phyllostachys edulis Compounds Inhibit Palmiti...
# 28   Correction: Investigating and Learning Lessons...
# 29   Sub-classification of myopic glaucomatous eyes...
# ..                                                 ...
# 970  Assessment of the Magnitude of Contextual and ...
# 971  Inference of Biological Pathway from Gene Expr...
# 972  Genistein Affects Histone Modifications on Dic...
# 973  Mild Transient Hypercapnia as a Novel Fear Con...
# 974  Pancreatic Stone Protein Predicts Postoperativ...
# 975  Correction: Abl Kinase Inhibits the Engulfment...
# 976  Prognostic Value of Serum Lactate Dehydrogenas...
# 977  Increasing Cervical Cancer Screening Coverage:...
# 978  Enterococcus durans TN-3 Induces Regulatory T ...
# 979  Evaluating the intensity of fire at the Acheul...
# 980  Nicotinic Receptor Alpha7 Expression during To...
# 981  Dust Devil: The Life and Times of the Fungus T...
# 982  Maintenance of Hepatic Functions in Primary Hu...
# 983  Incidence Patterns and Temporal Trends of Inva...
# 984                      The Human Genomic Melting Map
# 985  Evaluating Human T-Cell Therapy of Cytomegalov...
# 986  Characterization and Interactome Study of Whit...
# 987  Reducing Deaths from Severe Pneumonia in Child...
# 988  Mesopic Functional Visual Acuity in Normal Sub...
# 989  17β-Estradiol Enhances Signalling Mediated by ...
# 990  Development and Evaluation of a Rapid Antigen ...
# 991  De Novo Growth Zone Formation from Fission Yea...
# 992                   Sexual Selection Comes at a Cost
# 993  Toxic Accumulation of LPS Pathway Intermediate...
# 994  EP4 Receptor–Associated Protein in Macrophages...
# 995  The Yule Approximation for the Site Frequency ...
# 996  Correction: GLP2-2G-XTEN: A Pharmaceutical Pro...
# 997  MicroRNA-377 Regulates Mesenchymal Stem Cell-I...
# 998  A Functional Genomics Approach Identifies Cand...
# 999  Role of the Vasohibin Family in the Regulation...
#
#                                         tokenized_text  word_counts  \
# 0    [The, study, of, animal, communication, is, a,...         2239
# 1    [Aneurysms, in, general, represent, a, Damocle...         5547
# 2    [Prognostic, information, about, life, expecta...         4275
# 3    [Interleukin, (, IL, ), -23, has, been, associ...         5091
# 4    [Labor, represents, a, stress, test, for, the,...         3149
# 5    [Competition, has, long, been, recognized, as,...         6629
# 6    [There, were, errors, in, the, legend, of, Fig...          338
# 7    [Phylogeographic, studies, leverage, spatial, ...        11241
# 8    [Insulin-like, Growth, Factor-1, (, IGF-1, ), ...         5290
# 9    [Despite, the, expansive, development, of, tar...         6722
# 10   [Many, genetic, studies, of, complex, diseases...         5398
# 11   [How, our, brains, acquire, stable, cognitive,...        11922
# 12   [The, management, of, fragility, fractures, as...         4065
# 13   [Lymphangiogenesis, is, the, process, that, fo...         3319
# 14   [Novel, benzaldehyde, compounds, containing, b...         5762
# 15   [Although, there, are, no, systematic, differe...         7991
# 16   [According, to, the, definition, of, the, US, ...         4259
# 17   [About, 10, %, of, the, 135, million, babies, ...         4240
# 18   [Fetal, growth, is, under, the, control, of, g...         3184
# 19   [From, 2005, through, 2009, ,, the, number, of...         2545
# 20   [Dengue, and, dengue, hemorrhagic, fever, (, D...         5965
# 21   [In, surgery, ,, the, results, of, a, randomiz...         4654
# 22   [Cost-of-illness, (, COI, ), studies, provide,...         4166
# 23   [Vaccination, against, rumen, methanogens, has...         6325
# 24   [MicroRNAs, (, miRNAs, ), belong, to, a, group...         5003
# 25   [Clear, cell, carcinoma, (, CCC, ), of, the, o...         6444
# 26   [Senescence, is, the, physiological, deteriora...         7982
# 27   [Chronic, inflammation, is, associated, with, ...         6231
# 28   [Text, was, erroneously, omitted, from, Figure...           20
# 29   [Myopia, has, been, shown, to, be, a, risk, fa...         4261
# ..                                                 ...          ...
# 970  [In, the, past, two, decades, there, has, been...         4151
# 971  [In, order, to, understand, complex, biologica...         5257
# 972  [Soy, contains, various, bioactive, components...         7856
# 973  [An, emerging, literature, suggests, that, pos...         6692
# 974  [Despite, decades, of, intensive, research, an...         4639
# 975  [There, is, a, typographical, error, in, the, ...           75
# 976  [Renal, cell, carcinoma, (, RCC, ), is, a, com...         2702
# 977  [Despite, numerous, recommendations, calling, ...         3240
# 978  [Inflammatory, bowel, disease, (, IBD, ), ,, s...         3684
# 979  [The, use, of, fire, by, early, hominins, is, ...         4272
# 980  [Nicotinic, acetylcholine, receptors, (, nAChR...         7411
# 981  [Coccidioides, immitis, and, C., posadasii, ar...         2455
# 982  [During, the, cell, isolating, process, ,, hep...         4445
# 983  [Vulvar, carcinoma, is, a, rare, malignancy, ,...         3294
# 984  [Currently, ,, a, community-wide, effort, is, ...         9004
# 985  [Reactivation, of, latent, human, cytomegalovi...        10510
# 986  [White, spot, syndrome, virus, (, WSSV, ;, gen...         7981
# 987  [Pneumonia, is, the, most, frequent, cause, of...         6050
# 988  [Standard, visual, acuity, (, VA, ), ,, which,...         3386
# 989  [The, Notch, pathway, is, highly, conserved, f...         9599
# 990  [Foot-and-mouth, disease, (, FMD, ), is, one, ...         3703
# 991  [Cells, grow, with, a, wide, range, of, sizes,...         4392
# 992  [Males, evolved, extravagant, plumage, ,, towe...          895
# 993  [In, addition, to, the, cytoplasmic, phospholi...         8689
# 994  [The, incidence, of, inflammatory, bowel, dise...         8816
# 995  [Genetic, hitchhiking, is, the, cause, of, a, ...         3345
# 996  [Figure, 8, has, an, error, in, the, value, un...           24
# 997  [The, formation, of, new, blood, vessels, is, ...         5942
# 998  [Like, most, plant, parasites, ,, aphids, requ...         9251
# 999  [The, placenta, is, an, organ, that, connects,...         5344
#
#                                      normalized_tokens  \
# 0    [studi, anim, commun, complex, scienc, address...
# 1    [aneurysm, gener, repres, damocl, sword, class...
# 2    [prognost, inform, life, expect, older, peopl,...
# 3    [interleukin, il, ha, associ, develop, sever, ...
# 4    [labor, repres, stress, test, fetu, inde, feta...
# 5    [competit, ha, long, recogn, critic, process, ...
# 6    [error, legend, figur, correct, figur, legend,...
# 7    [phylogeograph, studi, leverag, spatial, genet...
# 8    [growth, potent, peptid, factor, involv, broad...
# 9    [despit, expans, develop, target, cancer, ther...
# 10   [mani, genet, studi, complex, diseas, interest...
# 11   [brain, acquir, stabl, cognit, map, spatial, e...
# 12   [manag, fragil, fractur, associ, osteoporosi, ...
# 13   [lymphangiogenesi, process, form, lymphat, ves...
# 14   [novel, benzaldehyd, compound, contain, benzim...
# 15   [although, systemat, differ, intellig, adult, ...
# 16   [accord, definit, us, institut, medicin, clini...
# 17   [million, babi, born, everi, year, deliv, pret...
# 18   [fetal, growth, control, genet, environment, n...
# 19   [number, peopl, low, incom, countri, take, hiv...
# 20   [dengu, dengu, hemorrhag, fever, df, dhf, resp...
# 21   [surgeri, result, random, control, trial, rct,...
# 22   [coi, studi, provid, estim, econom, impact, di...
# 23   [vaccin, rumen, methanogen, ha, potenti, reduc...
# 24   [microrna, mirna, belong, group, endogen, smal...
# 25   [clear, cell, carcinoma, ccc, ovari, known, le...
# 26   [senesc, physiolog, deterior, older, individu,...
# 27   [chronic, inflamm, associ, obes, mani, diseas,...
# 28   [text, wa, erron, omit, figur, correct, figur,...
# 29   [myopia, ha, shown, risk, factor, develop, gla...
# ..                                                 ...
# 970  [past, two, decad, ha, overal, increas, diabet...
# 971  [order, understand, complex, biolog, network, ...
# 972  [soy, contain, variou, bioactiv, compon, recei...
# 973  [emerg, literatur, suggest, posttraumat, stres...
# 974  [despit, decad, intens, research, constant, ev...
# 975  [typograph, error, titl, thi, articl, word, ap...
# 976  [renal, cell, carcinoma, rcc, common, malign, ...
# 977  [despit, numer, recommend, call, implement, or...
# 978  [inflammatori, bowel, diseas, ibd, ulcer, coli...
# 979  [use, fire, earli, hominin, consid, signific, ...
# 980  [nicotin, acetylcholin, receptor, nachr, addit...
# 981  [coccidioid, immiti, posadasii, pathogen, dimo...
# 982  [dure, cell, isol, process, hepatocyt, separ, ...
# 983  [vulvar, carcinoma, rare, malign, estim, world...
# 984  [current, effort, pursu, understand, genom, co...
# 985  [reactiv, latent, human, cytomegaloviru, hcmv,...
# 986  [white, spot, syndrom, viru, wssv, genu, whisp...
# 987  [pneumonia, frequent, caus, death, children, l...
# 988  [standard, visual, acuiti, va, reli, patient, ...
# 989  [notch, pathway, highli, conserv, invertebr, m...
# 990  [diseas, fmd, one, highli, contagi, viral, dis...
# 991  [cell, grow, wide, rang, size, morpholog, fiss...
# 992  [male, evolv, extravag, plumag, tower, antler,...
# 993  [addit, cytoplasm, phospholipid, membran, defi...
# 994  [incid, inflammatori, bowel, diseas, ibd, incr...
# 995  [genet, hitchhik, caus, sever, reduct, sequenc...
# 996  [figur, ha, error, valu, r, pleas, see, correc...
# 997  [format, new, blood, vessel, critic, repair, i...
# 998  [like, plant, parasit, aphid, requir, intim, a...
# 999  [placenta, organ, connect, fetu, matern, uteri...
#
#      normalized_tokens_count  \
# 0                       1055
# 1                       2663
# 2                       2011
# 3                       2413
# 4                       1543
# 5                       3029
# 6                        169
# 7                       5706
# 8                       2492
# 9                       3053
# 10                      2438
# 11                      5862
# 12                      1924
# 13                      1655
# 14                      2570
# 15                      3693
# 16                      1855
# 17                      2092
# 18                      1432
# 19                      1230
# 20                      2824
# 21                      2132
# 22                      2122
# 23                      2989
# 24                      2274
# 25                      2919
# 26                      3763
# 27                      2696
# 28                        11
# 29                      2122
# ..                       ...
# 970                     2040
# 971                     2369
# 972                     3582
# 973                     3364
# 974                     2431
# 975                       34
# 976                     1274
# 977                     1609
# 978                     1704
# 979                     2009
# 980                     3405
# 981                     1236
# 982                     2107
# 983                     1588
# 984                     4367
# 985                     4852
# 986                     3407
# 987                     3011
# 988                     1845
# 989                     4257
# 990                     1580
# 991                     2139
# 992                      501
# 993                     4071
# 994                     4041
# 995                     1385
# 996                       11
# 997                     2633
# 998                     4543
# 999                     2107
#
#                                        tokenized_sents  \
# 0    [[The, study, of, animal, communication, is, a...
# 1    [[Aneurysms, in, general, represent, a, Damocl...
# 2    [[Prognostic, information, about, life, expect...
# 3    [[Interleukin, (, IL, ), -23, has, been, assoc...
# 4    [[Labor, represents, a, stress, test, for, the...
# 5    [[Competition, has, long, been, recognized, as...
# 6    [[There, were, errors, in, the, legend, of, Fi...
# 7    [[Phylogeographic, studies, leverage, spatial,...
# 8    [[Insulin-like, Growth, Factor-1, (, IGF-1, ),...
# 9    [[Despite, the, expansive, development, of, ta...
# 10   [[Many, genetic, studies, of, complex, disease...
# 11   [[How, our, brains, acquire, stable, cognitive...
# 12   [[The, management, of, fragility, fractures, a...
# 13   [[Lymphangiogenesis, is, the, process, that, f...
# 14   [[Novel, benzaldehyde, compounds, containing, ...
# 15   [[Although, there, are, no, systematic, differ...
# 16   [[According, to, the, definition, of, the, US,...
# 17   [[About, 10, %, of, the, 135, million, babies,...
# 18   [[Fetal, growth, is, under, the, control, of, ...
# 19   [[From, 2005, through, 2009, ,, the, number, o...
# 20   [[Dengue, and, dengue, hemorrhagic, fever, (, ...
# 21   [[In, surgery, ,, the, results, of, a, randomi...
# 22   [[Cost-of-illness, (, COI, ), studies, provide...
# 23   [[Vaccination, against, rumen, methanogens, ha...
# 24   [[MicroRNAs, (, miRNAs, ), belong, to, a, grou...
# 25   [[Clear, cell, carcinoma, (, CCC, ), of, the, ...
# 26   [[Senescence, is, the, physiological, deterior...
# 27   [[Chronic, inflammation, is, associated, with,...
# 28   [[Text, was, erroneously, omitted, from, Figur...
# 29   [[Myopia, has, been, shown, to, be, a, risk, f...
# ..                                                 ...
# 970  [[In, the, past, two, decades, there, has, bee...
# 971  [[In, order, to, understand, complex, biologic...
# 972  [[Soy, contains, various, bioactive, component...
# 973  [[An, emerging, literature, suggests, that, po...
# 974  [[Despite, decades, of, intensive, research, a...
# 975  [[There, is, a, typographical, error, in, the,...
# 976  [[Renal, cell, carcinoma, (, RCC, ), is, a, co...
# 977  [[Despite, numerous, recommendations, calling,...
# 978  [[Inflammatory, bowel, disease, (, IBD, ), ,, ...
# 979  [[The, use, of, fire, by, early, hominins, is,...
# 980  [[Nicotinic, acetylcholine, receptors, (, nACh...
# 981  [[Coccidioides, immitis, and, C., posadasii, a...
# 982  [[During, the, cell, isolating, process, ,, he...
# 983  [[Vulvar, carcinoma, is, a, rare, malignancy, ...
# 984  [[Currently, ,, a, community-wide, effort, is,...
# 985  [[Reactivation, of, latent, human, cytomegalov...
# 986  [[White, spot, syndrome, virus, (, WSSV, ;, ge...
# 987  [[Pneumonia, is, the, most, frequent, cause, o...
# 988  [[Standard, visual, acuity, (, VA, ), ,, which...
# 989  [[The, Notch, pathway, is, highly, conserved, ...
# 990  [[Foot-and-mouth, disease, (, FMD, ), is, one,...
# 991  [[Cells, grow, with, a, wide, range, of, sizes...
# 992  [[Males, evolved, extravagant, plumage, ,, tow...
# 993  [[In, addition, to, the, cytoplasmic, phosphol...
# 994  [[The, incidence, of, inflammatory, bowel, dis...
# 995  [[Genetic, hitchhiking, is, the, cause, of, a,...
# 996  [[Figure, 8, has, an, error, in, the, value, u...
# 997  [[The, formation, of, new, blood, vessels, is,...
# 998  [[Like, most, plant, parasites, ,, aphids, req...
# 999  [[The, placenta, is, an, organ, that, connects...
#
#                                       normalized_sents
# 0    [[study, animal, communication, complex, scien...
# 1    [[aneurysms, general, represent, damocles, swo...
# 2    [[prognostic, information, life, expectancy, o...
# 3    [[interleukin, il, associated, development, se...
# 4    [[labor, represents, stress, test, fetus], [in...
# 5    [[competition, long, recognized, critical, pro...
# 6    [[errors, legend, figure], [correct, figure, l...
# 7    [[phylogeographic, studies, leverage, spatial,...
# 8    [[growth, potent, peptide, factor, involved, b...
# 9    [[despite, expansive, development, targeted, c...
# 10   [[many, genetic, studies, complex, diseases, i...
# 11   [[brains, acquire, stable, cognitive, maps, sp...
# 12   [[management, fragility, fractures, associated...
# 13   [[lymphangiogenesis, process, forms, lymphatic...
# 14   [[novel, benzaldehyde, compounds, containing, ...
# 15   [[although, systematic, differences, intellige...
# 16   [[according, definition, us, institute, medici...
# 17   [[million, babies, born, every, year, delivere...
# 18   [[fetal, growth, control, genetic, environment...
# 19   [[number, people, low, income, countries, taki...
# 20   [[dengue, dengue, hemorrhagic, fever, df, dhf,...
# 21   [[surgery, results, randomized, controlled, tr...
# 22   [[coi, studies, provide, estimates, economic, ...
# 23   [[vaccination, rumen, methanogens, potential, ...
# 24   [[micrornas, mirnas, belong, group, endogenous...
# 25   [[clear, cell, carcinoma, ccc, ovary, known, l...
# 26   [[senescence, physiological, deterioration, ol...
# 27   [[chronic, inflammation, associated, obesity, ...
# 28   [[text, erroneously, omitted, figure], [correc...
# 29   [[myopia, shown, risk, factor, development, gl...
# ..                                                 ...
# 970  [[past, two, decades, overall, increase, diabe...
# 971  [[order, understand, complex, biological, netw...
# 972  [[soy, contains, various, bioactive, component...
# 973  [[emerging, literature, suggests, posttraumati...
# 974  [[despite, decades, intensive, research, const...
# 975  [[typographical, error, title, article], [word...
# 976  [[renal, cell, carcinoma, rcc, common, maligna...
# 977  [[despite, numerous, recommendations, calling,...
# 978  [[inflammatory, bowel, disease, ibd, ulcerativ...
# 979  [[use, fire, early, hominins, considered, sign...
# 980  [[nicotinic, acetylcholine, receptors, nachr, ...
# 981  [[coccidioides, immitis, posadasii, pathogenic...
# 982  [[cell, isolating, process, hepatocytes, separ...
# 983  [[vulvar, carcinoma, rare, malignancy, estimat...
# 984  [[currently, effort, pursued, understand, geno...
# 985  [[reactivation, latent, human, cytomegalovirus...
# 986  [[white, spot, syndrome, virus, wssv, genus, w...
# 987  [[pneumonia, frequent, cause, death, children,...
# 988  [[standard, visual, acuity, va, relies, patien...
# 989  [[notch, pathway, highly, conserved, invertebr...
# 990  [[disease, fmd, one, highly, contagious, viral...
# 991  [[cells, grow, wide, range, sizes, morphologie...
# 992  [[males, evolved, extravagant, plumage, toweri...
# 993  [[addition, cytoplasmic, phospholipid, membran...
# 994  [[incidence, inflammatory, bowel, disease, ibd...
# 995  [[genetic, hitchhiking, cause, severe, reducti...
# 996  [[figure, error, value, r], [please, see, corr...
# 997  [[formation, new, blood, vessels, critical, re...
# 998  [[like, plant, parasites, aphids, require, int...
# 999  [[placenta, organ, connects, fetus, maternal, ...
#
# [1000 rows x 10 columns]

# %%
plos_df['normalized_sents'].iloc[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-dba2dba718a7> in <module>()
# ----> 1 plos_df['normalized_sents'].iloc[0]
#
# NameError: name 'plos_df' is not defined

# %%
pos_sents = stanford.postTagger.tag_sents(plos_df['tokenized_text'].iloc[0])
print(pos_sents)
# Out:
# [[('T', 'NN'), ('h', 'NN'), ('e', 'SYM')], [('s', 'NN'), ('t', 'NN'), ('u', 'NN'), ('d', 'NN'), ('y', 'NN')], [('o', 'NN'), ('f', 'SYM')], [('a', 'DT'), ('n', 'NN'), ('i', 'FW'), ('m', 'NN'), ('a', 'DT'), ('l', 'NN')], [('c', 'NN'), ('o', 'NN'), ('m', 'NN'), ('m', 'NN'), ('u', 'NN'), ('n', 'NN'), ('i', 'FW'), ('c', 'NN'), ('a', 'DT'), ('t', 'NN'), ('i', 'FW'), ('o', 'NN'), ('n', 'NN')], [('i', 'LS'), ('s', 'NN')], [('a', 'DT')], [('c', 'NN'), ('o', 'NN'), ('m', 'NN'), ('p', 'NN'), ('l', 'NN'), ('e', 'SYM'), ('x', 'NN')], [('s', 'NN'), ('c', 'NN'), ('i', 'FW'), ('e', 'LS'), ('n', 'NN'), ('c', 'NN'), ('e', 'SYM')], [('a', 'DT'), ('d', 'NN'), ('d', 'NN'), ('r', 'NN'), ('e', 'SYM'), ('s', 'NN'), ('s', 'VBZ'), ('i', 'LS'), ('n', 'NN'), ('g', 'NN')], [('a', 'DT')], [('w', 'FW'), ('i', 'FW'), ('d', 'FW'), ('e', 'SYM')], [('r', 'LS'), ('a', 'DT'), ('n', 'NN'), ('g', 'NN'), ('e', 'SYM')], [('o', 'NN'), ('f', 'SYM')], [('m', 'NN'), ('u', 'NN'), ('l', 'NN'), ('t', 'NN'), ('i', 'LS'), ('-', ':'), ('l', 'NN'), ('a', 'DT'), ('y', 'NN'), ('e', 'SYM'), ('r', 'LS'), ('e', 'LS'), ('d', 'NN')], [('q', 'FW'), ('u', 'FW'), ('e', 'LS'), ('s', 'NN'), ('t', 'NN'), ('i', 'FW'), ('o', 'NN'), ('n', 'NN'), ('s', 'NN')], [(',', ',')], [('s', 'NN'), ('u', 'NN'), ('c', 'NN'), ('h', 'NN')], [('a', 'DT'), ('s', 'NN')], [('h', 'NN'), ('o', 'NN'), ('w', 'NN')], [('a', 'DT')], [('s', 'NNS'), ('i', 'LS'), ('g', 'NN'), ('n', 'NN'), ('a', 'DT'), ('l', 'NN')], [('i', 'LS'), ('s', 'NN')], [('e', 'LS'), ('m', 'NN'), ('i', 'FW'), ('t', 'NN'), ('t', 'NN'), ('e', 'SYM'), ('d', 'NN')], [('(', 'NN')], [('e', 'LS'), ('.', '.'), ('g', 'NN'), ('.', '.')], [(',', ',')], [('v', 'LS'), ('i', 'LS'), ('s', 'NN'), ('u', 'NN'), ('a', 'DT'), ('l', 'NN'), ('l', 'NN'), ('y', 'NN')], [(',', ',')], [('a', 'DT'), ('c', 'NN'), ('o', 'NN'), ('u', 'NN'), ('s', 'NN'), ('t', 'NN'), ('i', 'FW'), ('c', 'NN'), ('a', 'DT'), ('l', 'NN'), ('l', 'NN'), ('y', 'NN')], [('e', 'LS'), ('t', 'NN'), ('c', 'NN')], [(')', 'NN')], [(',', ',')], [('h', 'NN'), ('o', 'NN'), ('w', 'NN')], [('i', 'LS'), ('t', 'NN')], [('i', 'LS'), ('s', 'NN')], [('p', 'NN'), ('e', 'SYM'), ('r', 'NN'), ('c', 'NN'), ('e', 'SYM'), ('i', 'FW'), ('v', 'LS'), ('e', 'LS'), ('d', 'NN')], [('(', 'NN')], [('e', 'LS'), ('.', '.'), ('g', 'NN')], [('.', '.')], [('t', 'NN'), ('h', 'NN'), ('e', 'SYM')], [('s', 'NN'), ('p', 'NN'), ('e', 'SYM'), ('c', 'NN'), ('t', 'NN'), ('r', 'NN'), ('a', 'DT'), ('l', 'NN')], [('r', 'LS'), ('a', 'DT'), ('n', 'NN'), ('g', 'NN'), ('e', 'SYM')], [('a', 'DT'), ('n', 'NN'), ('d', 'NN')], [('s', 'NNS'), ('e', 'LS'), ('n', 'NN'), ('s', 'VBZ'), ('i', 'LS'), ('t', 'NN'), ('i', 'FW'), ('v', 'LS'), ('i', 'LS'), ('t', 'NN'), ('y', 'NN')], [('o', 'NN'), ('f', 'SYM')], [('c', 'NN'), ('o', 'NN'), ('l', 'NN'), ('o', 'NN'), ('u', 'NN'), ('r', 'NN')], [('v', 'LS'), ('i', 'FW'), ('s', 'VBZ'), ('i', 'LS'), ('o', 'NN'), ('n', 'NN')], [(')', 'NN')], [(',', ',')], [('a', 'DT'), ('n', 'NN'), ('d', 'NN')], [('o', 'NN'), ('f', 'SYM')], [('c', 'NN'), ('o', 'NN'), ('u', 'NN'), ('r', 'NN'), ('s', 'VBZ'), ('e', 'SYM')], [('t', 'NN'), ('h', 'NN'), ('e', 'SYM')], [('a', 'DT'), ('d', 'NN'), ('a', 'DT'), ('p', 'NN'), ('t', 'NN'), ('i', 'FW'), ('v', 'LS'), ('e', 'SYM')], [('r', 'NN'), ('e', 'SYM'), ('a', 'DT'), ('s', 'NN'), ('o', 'NN'), ('n', 'NN'), ('s', 'NN')], [('f', 'LS'), ('o', 'NN'), ('r', 'NN')], [('s', 'NNS'), ('i', 'LS'), ('g', 'NN'), ('n', 'NN'), ('a', 'DT'), ('l', 'NN'), ('i', 'FW'), ('n', 'NN'), ('g', 'NN')], [('(', 'NN')], [('e', 'LS'), ('.', '.'), ('g', 'NN'), ('.', '.')], [(',', ',')], [('d', 'LS'), ('e', 'LS'), ('t', 'NN'), ('e', 'SYM'), ('r', 'NN'), ('r', 'NN'), ('i', 'FW'), ('n', 'NN'), ('g', 'NN')], [('r', 'LS'), ('i', 'LS'), ('v', 'LS'), ('a', 'DT'), ('l', 'NN'), ('s', 'NN')], [(',', ',')], [('a', 'DT'), ('t', 'NN'), ('t', 'NN'), ('r', 'NN'), ('a', 'DT'), ('c', 'NN'), ('t', 'NN'), ('i', 'FW'), ('n', 'NN'), ('g', 'NN')], [('m', 'NN'), ('a', 'DT'), ('t', 'NN'), ('e', 'SYM'), ('s', 'NN')], [(')', 'NN')], [('.', '.')], [('A', 'DT'), ...
